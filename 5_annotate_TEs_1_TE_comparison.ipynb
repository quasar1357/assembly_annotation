# %% [markdown]
# Class | Sha | Ler_3 | Cvi_0 | C24 | An_1
# -|-|-|-|-|-
# **LTR** |-|-|-|-|-
# Copia| 1.25% | 1.08% | 1.19% | 1.11% | 1.11%
# Gypsy| 4.62% | 4.62% | 4.69% | 4.39% | 5.05%
# unknown| 0.43% | 0.69% | 0.60% | 0.54% | 0.39%
# **TIR** |-|-|-|-|-
# CACTA| 0.62% | 0.69% | 0.00% | 0.71% | 0.52%
# Mutator| 0.80% | 0.79% | 0.01% | 0.62% | 0.51%
# PIF_Harbinger| 0.24% | 0.20% | 0.00% | 0.11% | 0.14%
# Tc1_Mariner | 0.04% | 0.03% | 0.00% | 0.13% | 0.12%
# hAT | 0.22% | 0.28% | 0.01% | 0.21% | 0.21%
# **nonTIR**|-|-|-|-|-
# helitron| 4.98% | 4.92% | 6.57% | 5.00% | 5.32%
# -|-|-|-|-|-
# total | 13.20% | 13.29% | 13.06% | 12.82% | 13.36%

# %%
import matplotlib.pyplot as plt

# Data
categories = ['Copia', 'Gypsy', 'other LTR', 'CACTA', 'Mutator', 'PIF_Harbinger', 'Tc1_Mariner', 'hAT',  'helitron']
Sha = [1.25, 4.62, 0.43, 0.62, 0.80, 0.24, 0.04, 0.22, 4.98]
Ler_3 = [1.08, 4.62, 0.69, 0.69, 0.79, 0.20, 0.03, 0.28, 4.92]
Cvi_0 = [1.19, 4.69, 0.60, 0.00, 0.01, 0, 0.00, 0.01, 6.57]
C24 = [1.11, 4.39, 0.54, 0.71, 0.62, 0.11, 0.13, 0.21, 5.00]
An_1 = [1.11, 5.05, 0.39, 0.52, 0.51, 0.14, 0.12, 0.21, 5.32]

# Plotting
x = range(len(categories))
w = 0.18
colors=['blue', 'orange', 'green', 'red', 'purple']
plt.bar(x, Sha, width=w, label='Sha', color=colors[0], alpha=0.6)
plt.bar([i + w for i in x], Ler_3, width=w, label='Ler_3', color=colors[1], alpha=0.6)#, color='green')
plt.bar([i + 2*w for i in x], Cvi_0, width=w, label='Cvi_0', color=colors[2], alpha=0.6)#, color='lightgreen')
plt.bar([i + 3*w for i in x], C24, width=w, label='C24', color=colors[3], alpha=0.6)#, color='lightgreen')
plt.bar([i + 4*w for i in x], An_1, width=w, label='An_1', color=colors[4], alpha=0.6)#, color='lightblue')

# Customize the plot
plt.xlabel('Class')
plt.ylabel('Percentage')
plt.title('TE Comparison')
plt.xticks([i + 0.3 for i in x], categories, rotation=45)
plt.legend( bbox_to_anchor=(0.5, 0.85), loc='upper left', borderaxespad=0.)

# Remove top and right borders
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Show the plot
plt.show()
